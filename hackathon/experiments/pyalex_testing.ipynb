# %%
from pyalex import Works, Authors, Sources, Institutions, Topics, Publishers, Funders
import json

# %%
w = Works().search_filter(title="Mice in Bion-M 1 space mission: training and selection").get()

# %%
# Use first search result
w = w[0]

# %%
w
# Out:
# {'id': 'https://openalex.org/W2024980514',
#  'doi': 'https://doi.org/10.1371/journal.pone.0104830',
#  'title': 'Mice in Bion-M 1 Space Mission: Training and Selection',
#  'display_name': 'Mice in Bion-M 1 Space Mission: Training and Selection',
#  'relevance_score': 1827.8414,
#  'publication_year': 2014,
#  'publication_date': '2014-08-18',
#  'ids': {'openalex': 'https://openalex.org/W2024980514',
#   'doi': 'https://doi.org/10.1371/journal.pone.0104830',
#   'mag': '2024980514',
#   'pmid': 'https://pubmed.ncbi.nlm.nih.gov/25133741',
#   'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/4136787'},
#  'language': 'en',
#  'primary_location': {'is_oa': True,
#   'landing_page_url': 'https://doi.org/10.1371/journal.pone.0104830',
#   'pdf_url': 'https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0104830&type=printable',
#   'source': {'id': 'https://openalex.org/S202381698',
#    'display_name': 'PLoS ONE',
#    'issn_l': '1932-6203',
#    'issn': ['1932-6203'],
#    'is_oa': True,
#    'is_in_doaj': True,
#    'is_indexed_in_scopus': True,
#    'is_core': True,
#    'host_organization': 'https://openalex.org/P4310315706',
#    'host_organization_name': 'Public Library of Science',
#    'host_organization_lineage': ['https://openalex.org/P4310315706'],
#    'host_organization_lineage_names': ['Public Library of Science'],
#    'type': 'journal'},
#   'license': 'cc-by',
#   'license_id': 'https://openalex.org/licenses/cc-by',
#   'version': 'publishedVersion',
#   'is_accepted': True,
#   'is_published': True},
#  'type': 'article',
#  'type_crossref': 'journal-article',
#  'indexed_in': ['crossref', 'doaj', 'pubmed'],
#  'open_access': {'is_oa': True,
#   'oa_status': 'gold',
#   'oa_url': 'https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0104830&type=printable',
#   'any_repository_has_fulltext': True},
#  'authorships': [{'author_position': 'first',
#    'author': {'id': 'https://openalex.org/A5007682145',
#     'display_name': 'Alexander Andreev‐Andrievskiy',
#     'orcid': 'https://orcid.org/0000-0002-1173-8153'},
#    'institutions': [{'id': 'https://openalex.org/I4210101246',
#      'display_name': 'Institute of Biomedical Problems',
#      'ror': 'https://ror.org/016hfp155',
#      'country_code': 'RU',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I1313323035',
#       'https://openalex.org/I4210101246',
#       'https://openalex.org/I4210115279']},
#     {'id': 'https://openalex.org/I19880235',
#      'display_name': 'Lomonosov Moscow State University',
#      'ror': 'https://ror.org/010pmpe69',
#      'country_code': 'RU',
#      'type': 'funder',
#      'lineage': ['https://openalex.org/I19880235']}],
#    'countries': ['RU'],
#    'is_corresponding': True,
#    'raw_author_name': 'Alexander Andreev-Andrievskiy',
#    'raw_affiliation_strings': ['Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia',
#     'Moscow State University, Biology Faculty, Moscow, Russia'],
#    'affiliations': [{'raw_affiliation_string': 'Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I4210101246']},
#     {'raw_affiliation_string': 'Moscow State University, Biology Faculty, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I19880235']}]},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5102865109',
#     'display_name': 'Anfisa Popova',
#     'orcid': 'https://orcid.org/0000-0002-7827-9764'},
#    'institutions': [{'id': 'https://openalex.org/I4210101246',
#      'display_name': 'Institute of Biomedical Problems',
#      'ror': 'https://ror.org/016hfp155',
#      'country_code': 'RU',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I1313323035',
#       'https://openalex.org/I4210101246',
#       'https://openalex.org/I4210115279']},
#     {'id': 'https://openalex.org/I19880235',
#      'display_name': 'Lomonosov Moscow State University',
#      'ror': 'https://ror.org/010pmpe69',
#      'country_code': 'RU',
#      'type': 'funder',
#      'lineage': ['https://openalex.org/I19880235']}],
#    'countries': ['RU'],
#    'is_corresponding': True,
#    'raw_author_name': 'Anfisa Popova',
#    'raw_affiliation_strings': ['Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia',
#     'Moscow State University, Biology Faculty, Moscow, Russia'],
#    'affiliations': [{'raw_affiliation_string': 'Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I4210101246']},
#     {'raw_affiliation_string': 'Moscow State University, Biology Faculty, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I19880235']}]},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5102855830',
#     'display_name': 'Richard Boyle',
#     'orcid': 'https://orcid.org/0000-0001-9305-5024'},
#    'institutions': [{'id': 'https://openalex.org/I1280536761',
#      'display_name': 'Ames Research Center',
#      'ror': 'https://ror.org/02acart68',
#      'country_code': 'US',
#      'type': 'funder',
#      'lineage': ['https://openalex.org/I1280536761',
#       'https://openalex.org/I4210124779']}],
#    'countries': ['US'],
#    'is_corresponding': True,
#    'raw_author_name': 'Richard Boyle',
#    'raw_affiliation_strings': ['Bio-Visualization, Imaging and Simulation Technology Center (BioVIS), NASA Ames Research Center, Moffett Field, California, United States of America'],
#    'affiliations': [{'raw_affiliation_string': 'Bio-Visualization, Imaging and Simulation Technology Center (BioVIS), NASA Ames Research Center, Moffett Field, California, United States of America',
#      'institution_ids': ['https://openalex.org/I1280536761']}]},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5003466788',
#     'display_name': 'Jeffrey R. Alberts',
#     'orcid': 'https://orcid.org/0000-0003-2104-6297'},
#    'institutions': [{'id': 'https://openalex.org/I4210119109',
#      'display_name': 'Indiana University Bloomington',
#      'ror': 'https://ror.org/02k40bc56',
#      'country_code': 'US',
#      'type': 'funder',
#      'lineage': ['https://openalex.org/I4210119109',
#       'https://openalex.org/I592451']}],
#    'countries': ['US'],
#    'is_corresponding': True,
#    'raw_author_name': 'Jeffrey Alberts',
#    'raw_affiliation_strings': ['Indiana University, Department of Psychological and Brain Sciences, Bloomington, Indiana, United States of America'],
#    'affiliations': [{'raw_affiliation_string': 'Indiana University, Department of Psychological and Brain Sciences, Bloomington, Indiana, United States of America',
#      'institution_ids': ['https://openalex.org/I4210119109']}]},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5103900094',
#     'display_name': 'Boris Shenkman',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I4210101246',
#      'display_name': 'Institute of Biomedical Problems',
#      'ror': 'https://ror.org/016hfp155',
#      'country_code': 'RU',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I1313323035',
#       'https://openalex.org/I4210101246',
#       'https://openalex.org/I4210115279']}],
#    'countries': ['RU'],
#    'is_corresponding': True,
#    'raw_author_name': 'Boris Shenkman',
#    'raw_affiliation_strings': ['Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia'],
#    'affiliations': [{'raw_affiliation_string': 'Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I4210101246']}]},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5108039862',
#     'display_name': 'О. Л. Виноградова',
#     'orcid': 'https://orcid.org/0000-0002-4622-0522'},
#    'institutions': [{'id': 'https://openalex.org/I4210101246',
#      'display_name': 'Institute of Biomedical Problems',
#      'ror': 'https://ror.org/016hfp155',
#      'country_code': 'RU',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I1313323035',
#       'https://openalex.org/I4210101246',
#       'https://openalex.org/I4210115279']}],
#    'countries': ['RU'],
#    'is_corresponding': True,
#    'raw_author_name': 'Olga Vinogradova',
#    'raw_affiliation_strings': ['Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia'],
#    'affiliations': [{'raw_affiliation_string': 'Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I4210101246']}]},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5000072952',
#     'display_name': 'Oleg Dolgov',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I4210154072',
#      'display_name': 'Institute of Normal Physiology named after P.K. Anokhin',
#      'ror': 'https://ror.org/04kakt857',
#      'country_code': 'RU',
#      'type': 'funder',
#      'lineage': ['https://openalex.org/I1313323035',
#       'https://openalex.org/I4210110862',
#       'https://openalex.org/I4210154072']}],
#    'countries': ['RU'],
#    'is_corresponding': True,
#    'raw_author_name': 'Oleg Dolgov',
#    'raw_affiliation_strings': ['Anokhin Institute of Normal Physiology, Russian Academy of Medical Sciences, Moscow, Russia'],
#    'affiliations': [{'raw_affiliation_string': 'Anokhin Institute of Normal Physiology, Russian Academy of Medical Sciences, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I4210154072']}]},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5007929999',
#     'display_name': 'K. V. Anokhin',
#     'orcid': 'https://orcid.org/0000-0003-4437-6002'},
#    'institutions': [{'id': 'https://openalex.org/I2800235667',
#      'display_name': 'Kurchatov Institute',
#      'ror': 'https://ror.org/00n1nz186',
#      'country_code': 'RU',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I2800235667']},
#     {'id': 'https://openalex.org/I4210154072',
#      'display_name': 'Institute of Normal Physiology named after P.K. Anokhin',
#      'ror': 'https://ror.org/04kakt857',
#      'country_code': 'RU',
#      'type': 'funder',
#      'lineage': ['https://openalex.org/I1313323035',
#       'https://openalex.org/I4210110862',
#       'https://openalex.org/I4210154072']}],
#    'countries': ['RU'],
#    'is_corresponding': True,
#    'raw_author_name': 'Konstantin Anokhin',
#    'raw_affiliation_strings': ['Anokhin Institute of Normal Physiology, Russian Academy of Medical Sciences, Moscow, Russia',
#     'Kurchatov NBIC-center, National Research Centre "Kurchatov Institute", Moscow, Russia'],
#    'affiliations': [{'raw_affiliation_string': 'Kurchatov NBIC-center, National Research Centre "Kurchatov Institute", Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I2800235667']},
#     {'raw_affiliation_string': 'Anokhin Institute of Normal Physiology, Russian Academy of Medical Sciences, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I4210154072']}]},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5065942851',
#     'display_name': 'Daria Tsvirkun',
#     'orcid': 'https://orcid.org/0000-0002-6599-6844'},
#    'institutions': [{'id': 'https://openalex.org/I4210101246',
#      'display_name': 'Institute of Biomedical Problems',
#      'ror': 'https://ror.org/016hfp155',
#      'country_code': 'RU',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I1313323035',
#       'https://openalex.org/I4210101246',
#       'https://openalex.org/I4210115279']}],
#    'countries': ['RU'],
#    'is_corresponding': True,
#    'raw_author_name': 'Darya Tsvirkun',
#    'raw_affiliation_strings': ['Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia'],
#    'affiliations': [{'raw_affiliation_string': 'Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I4210101246']}]},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5003302980',
#     'display_name': 'П. Е. Солдатов',
#     'orcid': 'https://orcid.org/0000-0002-5318-4531'},
#    'institutions': [{'id': 'https://openalex.org/I4210101246',
#      'display_name': 'Institute of Biomedical Problems',
#      'ror': 'https://ror.org/016hfp155',
#      'country_code': 'RU',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I1313323035',
#       'https://openalex.org/I4210101246',
#       'https://openalex.org/I4210115279']}],
#    'countries': ['RU'],
#    'is_corresponding': True,
#    'raw_author_name': 'Pavel Soldatov',
#    'raw_affiliation_strings': ['Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia'],
#    'affiliations': [{'raw_affiliation_string': 'Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I4210101246']}]},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5103394824',
#     'display_name': 'Tatyana L. Nemirovskaya',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I4210101246',
#      'display_name': 'Institute of Biomedical Problems',
#      'ror': 'https://ror.org/016hfp155',
#      'country_code': 'RU',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I1313323035',
#       'https://openalex.org/I4210101246',
#       'https://openalex.org/I4210115279']}],
#    'countries': ['RU'],
#    'is_corresponding': True,
#    'raw_author_name': 'Tatyana Nemirovskaya',
#    'raw_affiliation_strings': ['Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia'],
#    'affiliations': [{'raw_affiliation_string': 'Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I4210101246']}]},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5111514436',
#     'display_name': 'Е.А. Ilyin',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I4210101246',
#      'display_name': 'Institute of Biomedical Problems',
#      'ror': 'https://ror.org/016hfp155',
#      'country_code': 'RU',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I1313323035',
#       'https://openalex.org/I4210101246',
#       'https://openalex.org/I4210115279']}],
#    'countries': ['RU'],
#    'is_corresponding': True,
#    'raw_author_name': 'Eugeniy Ilyin',
#    'raw_affiliation_strings': ['Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia'],
#    'affiliations': [{'raw_affiliation_string': 'Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I4210101246']}]},
#   {'author_position': 'last',
#    'author': {'id': 'https://openalex.org/A5088403596',
#     'display_name': 'Vladimir Sychev',
#     'orcid': 'https://orcid.org/0000-0001-7508-9087'},
#    'institutions': [{'id': 'https://openalex.org/I4210101246',
#      'display_name': 'Institute of Biomedical Problems',
#      'ror': 'https://ror.org/016hfp155',
#      'country_code': 'RU',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I1313323035',
#       'https://openalex.org/I4210101246',
#       'https://openalex.org/I4210115279']}],
#    'countries': ['RU'],
#    'is_corresponding': True,
#    'raw_author_name': 'Vladimir Sychev',
#    'raw_affiliation_strings': ['Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia'],
#    'affiliations': [{'raw_affiliation_string': 'Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia',
#      'institution_ids': ['https://openalex.org/I4210101246']}]}],
#  'institution_assertions': [],
#  'countries_distinct_count': 2,
#  'institutions_distinct_count': 6,
#  'corresponding_author_ids': ['https://openalex.org/A5007682145',
#   'https://openalex.org/A5102865109',
#   'https://openalex.org/A5102855830',
#   'https://openalex.org/A5003466788',
#   'https://openalex.org/A5103900094',
#   'https://openalex.org/A5108039862',
#   'https://openalex.org/A5000072952',
#   'https://openalex.org/A5007929999',
#   'https://openalex.org/A5065942851',
#   'https://openalex.org/A5003302980',
#   'https://openalex.org/A5103394824',
#   'https://openalex.org/A5111514436',
#   'https://openalex.org/A5088403596'],
#  'corresponding_institution_ids': ['https://openalex.org/I4210101246',
#   'https://openalex.org/I19880235',
#   'https://openalex.org/I4210101246',
#   'https://openalex.org/I19880235',
#   'https://openalex.org/I1280536761',
#   'https://openalex.org/I4210119109',
#   'https://openalex.org/I4210101246',
#   'https://openalex.org/I4210101246',
#   'https://openalex.org/I4210154072',
#   'https://openalex.org/I2800235667',
#   'https://openalex.org/I4210154072',
#   'https://openalex.org/I4210101246',
#   'https://openalex.org/I4210101246',
#   'https://openalex.org/I4210101246',
#   'https://openalex.org/I4210101246',
#   'https://openalex.org/I4210101246'],
#  'apc_list': {'value': 1805, 'currency': 'USD', 'value_usd': 1805},
#  'apc_paid': {'value': 1805, 'currency': 'USD', 'value_usd': 1805},
#  'fwci': 4.703,
#  'has_fulltext': True,
#  'fulltext_origin': 'pdf',
#  'cited_by_count': 91,
#  'citation_normalized_percentile': {'value': 0.999952,
#   'is_in_top_1_percent': True,
#   'is_in_top_10_percent': True},
#  'cited_by_percentile_year': {'min': 97, 'max': 98},
#  'biblio': {'volume': '9',
#   'issue': '8',
#   'first_page': 'e104830',
#   'last_page': 'e104830'},
#  'is_retracted': False,
#  'is_paratext': False,
#  'primary_topic': {'id': 'https://openalex.org/T12005',
#   'display_name': 'Spaceflight effects on biology',
#   'score': 0.9995,
#   'subfield': {'id': 'https://openalex.org/subfields/2737',
#    'display_name': 'Physiology'},
#   'field': {'id': 'https://openalex.org/fields/27',
#    'display_name': 'Medicine'},
#   'domain': {'id': 'https://openalex.org/domains/4',
#    'display_name': 'Health Sciences'}},
#  'topics': [{'id': 'https://openalex.org/T12005',
#    'display_name': 'Spaceflight effects on biology',
#    'score': 0.9995,
#    'subfield': {'id': 'https://openalex.org/subfields/2737',
#     'display_name': 'Physiology'},
#    'field': {'id': 'https://openalex.org/fields/27',
#     'display_name': 'Medicine'},
#    'domain': {'id': 'https://openalex.org/domains/4',
#     'display_name': 'Health Sciences'}}],
#  'keywords': [],
#  'concepts': [{'id': 'https://openalex.org/C81917197',
#    'wikidata': 'https://www.wikidata.org/wiki/Q628760',
#    'display_name': 'Selection (genetic algorithm)',
#    'level': 2,
#    'score': 0.57971156},
#   {'id': 'https://openalex.org/C2778572836',
#    'wikidata': 'https://www.wikidata.org/wiki/Q380933',
#    'display_name': 'Space (punctuation)',
#    'level': 2,
#    'score': 0.45162693},
#   {'id': 'https://openalex.org/C70721500',
#    'wikidata': 'https://www.wikidata.org/wiki/Q177005',
#    'display_name': 'Computational biology',
#    'level': 1,
#    'score': 0.43779275},
#   {'id': 'https://openalex.org/C41008148',
#    'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#    'display_name': 'Computer science',
#    'level': 0,
#    'score': 0.37105697},
#   {'id': 'https://openalex.org/C86803240',
#    'wikidata': 'https://www.wikidata.org/wiki/Q420',
#    'display_name': 'Biology',
#    'level': 0,
#    'score': 0.34196806},
#   {'id': 'https://openalex.org/C154945302',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#    'display_name': 'Artificial intelligence',
#    'level': 1,
#    'score': 0.25689316},
#   {'id': 'https://openalex.org/C111919701',
#    'wikidata': 'https://www.wikidata.org/wiki/Q9135',
#    'display_name': 'Operating system',
#    'level': 1,
#    'score': 0.0}],
#  'mesh': [{'descriptor_ui': 'D000222',
#    'descriptor_name': 'Adaptation, Physiological',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D000818',
#    'descriptor_name': 'Animals',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D035843',
#    'descriptor_name': 'Biomedical Research',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D004435',
#    'descriptor_name': 'Eating',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D006799',
#    'descriptor_name': 'Housing, Animal',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D008297',
#    'descriptor_name': 'Male',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D008810',
#    'descriptor_name': 'Mice, Inbred C57BL',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D010805',
#    'descriptor_name': 'Physical Conditioning, Animal',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D012107',
#    'descriptor_name': 'Research Design',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D012426',
#    'descriptor_name': 'Russia',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D013026',
#    'descriptor_name': 'Space Flight',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D014893',
#    'descriptor_name': 'Weightlessness',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False}],
#  'locations_count': 5,
#  'locations': [{'is_oa': True,
#    'landing_page_url': 'https://doi.org/10.1371/journal.pone.0104830',
#    'pdf_url': 'https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0104830&type=printable',
#    'source': {'id': 'https://openalex.org/S202381698',
#     'display_name': 'PLoS ONE',
#     'issn_l': '1932-6203',
#     'issn': ['1932-6203'],
#     'is_oa': True,
#     'is_in_doaj': True,
#     'is_indexed_in_scopus': True,
#     'is_core': True,
#     'host_organization': 'https://openalex.org/P4310315706',
#     'host_organization_name': 'Public Library of Science',
#     'host_organization_lineage': ['https://openalex.org/P4310315706'],
#     'host_organization_lineage_names': ['Public Library of Science'],
#     'type': 'journal'},
#    'license': 'cc-by',
#    'license_id': 'https://openalex.org/licenses/cc-by',
#    'version': 'publishedVersion',
#    'is_accepted': True,
#    'is_published': True},
#   {'is_oa': False,
#    'landing_page_url': 'https://doaj.org/article/9468c812a611470697eb46b323210b04',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306401280',
#     'display_name': 'DOAJ (DOAJ: Directory of Open Access Journals)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'is_indexed_in_scopus': False,
#     'is_core': False,
#     'host_organization': None,
#     'host_organization_name': None,
#     'host_organization_lineage': [],
#     'host_organization_lineage_names': [],
#     'type': 'repository'},
#    'license': None,
#    'license_id': None,
#    'version': None,
#    'is_accepted': False,
#    'is_published': False},
#   {'is_oa': True,
#    'landing_page_url': 'https://europepmc.org/articles/pmc4136787',
#    'pdf_url': 'https://europepmc.org/articles/pmc4136787?pdf=render',
#    'source': {'id': 'https://openalex.org/S4306400806',
#     'display_name': 'Europe PMC (PubMed Central)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'is_indexed_in_scopus': False,
#     'is_core': False,
#     'host_organization': 'https://openalex.org/I1303153112',
#     'host_organization_name': 'European Bioinformatics Institute',
#     'host_organization_lineage': ['https://openalex.org/I1303153112'],
#     'host_organization_lineage_names': ['European Bioinformatics Institute'],
#     'type': 'repository'},
#    'license': None,
#    'license_id': None,
#    'version': 'publishedVersion',
#    'is_accepted': True,
#    'is_published': True},
#   {'is_oa': True,
#    'landing_page_url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4136787',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S2764455111',
#     'display_name': 'PubMed Central',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'is_indexed_in_scopus': False,
#     'is_core': False,
#     'host_organization': 'https://openalex.org/I1299303238',
#     'host_organization_name': 'National Institutes of Health',
#     'host_organization_lineage': ['https://openalex.org/I1299303238'],
#     'host_organization_lineage_names': ['National Institutes of Health'],
#     'type': 'repository'},
#    'license': None,
#    'license_id': None,
#    'version': 'publishedVersion',
#    'is_accepted': True,
#    'is_published': True},
#   {'is_oa': False,
#    'landing_page_url': 'https://pubmed.ncbi.nlm.nih.gov/25133741',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306525036',
#     'display_name': 'PubMed',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': False,
#     'is_in_doaj': False,
#     'is_indexed_in_scopus': False,
#     'is_core': False,
#     'host_organization': 'https://openalex.org/I1299303238',
#     'host_organization_name': 'National Institutes of Health',
#     'host_organization_lineage': ['https://openalex.org/I1299303238'],
#     'host_organization_lineage_names': ['National Institutes of Health'],
#     'type': 'repository'},
#    'license': None,
#    'license_id': None,
#    'version': None,
#    'is_accepted': False,
#    'is_published': False}],
#  'best_oa_location': {'is_oa': True,
#   'landing_page_url': 'https://doi.org/10.1371/journal.pone.0104830',
#   'pdf_url': 'https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0104830&type=printable',
#   'source': {'id': 'https://openalex.org/S202381698',
#    'display_name': 'PLoS ONE',
#    'issn_l': '1932-6203',
#    'issn': ['1932-6203'],
#    'is_oa': True,
#    'is_in_doaj': True,
#    'is_indexed_in_scopus': True,
#    'is_core': True,
#    'host_organization': 'https://openalex.org/P4310315706',
#    'host_organization_name': 'Public Library of Science',
#    'host_organization_lineage': ['https://openalex.org/P4310315706'],
#    'host_organization_lineage_names': ['Public Library of Science'],
#    'type': 'journal'},
#   'license': 'cc-by',
#   'license_id': 'https://openalex.org/licenses/cc-by',
#   'version': 'publishedVersion',
#   'is_accepted': True,
#   'is_published': True},
#  'sustainable_development_goals': [],
#  'grants': [],
#  'datasets': [],
#  'versions': [],
#  'referenced_works_count': 37,
#  'referenced_works': ['https://openalex.org/W1505364969',
#   'https://openalex.org/W1554739571',
#   'https://openalex.org/W1591327376',
#   'https://openalex.org/W1619036177',
#   'https://openalex.org/W1969581053',
#   'https://openalex.org/W1971410406',
#   'https://openalex.org/W1971846039',
#   'https://openalex.org/W1983439863',
#   'https://openalex.org/W1987412703',
#   'https://openalex.org/W1993340066',
#   'https://openalex.org/W1997095406',
#   'https://openalex.org/W1999858993',
#   'https://openalex.org/W2007302154',
#   'https://openalex.org/W2018002860',
#   'https://openalex.org/W2032606415',
#   'https://openalex.org/W2037241677',
#   'https://openalex.org/W2044143697',
#   'https://openalex.org/W2056883423',
#   'https://openalex.org/W2058934156',
#   'https://openalex.org/W2063848772',
#   'https://openalex.org/W2087151156',
#   'https://openalex.org/W2089680506',
#   'https://openalex.org/W2095510407',
#   'https://openalex.org/W2096916192',
#   'https://openalex.org/W2101954244',
#   'https://openalex.org/W2123250581',
#   'https://openalex.org/W2137856862',
#   'https://openalex.org/W2146215923',
#   'https://openalex.org/W2160801689',
#   'https://openalex.org/W2169205637',
#   'https://openalex.org/W2184493357',
#   'https://openalex.org/W2416126827',
#   'https://openalex.org/W2487019969',
#   'https://openalex.org/W2955504961',
#   'https://openalex.org/W4232424793',
#   'https://openalex.org/W569272410',
#   'https://openalex.org/W9377703'],
#  'related_works': ['https://openalex.org/W4391375266',
#   'https://openalex.org/W2899084033',
#   'https://openalex.org/W2788277189',
#   'https://openalex.org/W2748952813',
#   'https://openalex.org/W2130076355',
#   'https://openalex.org/W2119695867',
#   'https://openalex.org/W2082860237',
#   'https://openalex.org/W2046158694',
#   'https://openalex.org/W1993764875',
#   'https://openalex.org/W1990804418'],
#  'abstract_inverted_index': {'After': [0, 243],
#   'a': [1],
#   '16-year': [2],
#   'hiatus,': [3],
#   'Russia': [4],
#   'has': [5],
#   'resumed': [6],
#   'its': [7],
#   'program': [8, 207, 268, 280],
#   'of': [9, 19, 45, 59, 77, 114, 121, 199, 231, 240, 257, 265],
#   'biomedical': [10, 32, 252, 293],
#   'research': [11, 33],
#   'in': [12,
#    34,
#    62,
#    84,
#    91,
#    95,
#    106,
#    118,
#    129,
#    143,
#    153,
#    175,
#    193,
#    212,
#    226,
#    248,
#    291],
#   'space,': [13],
#   'with': [14, 88, 104],
#   'the': [15,
#    20,
#    38,
#    46,
#    49,
#    53,
#    63,
#    75,
#    115,
#    119,
#    135,
#    144,
#    154,
#    173,
#    197,
#    227,
#    232,
#    238,
#    244,
#    266,
#    270],
#   'successful': [16],
#   '30-day': [17],
#   'flight': [18, 96],
#   'Bion-M': [21, 64, 136],
#   '1': [22, 65, 137],
#   'biosatellite': [23],
#   '(April': [24],
#   '19-May': [25],
#   '19,': [26],
#   '2013).': [27],
#   'The': [28, 57, 86, 185, 205, 229, 263],
#   'principal': [29],
#   'species': [30],
#   'for': [31, 163, 208, 211, 237, 251, 269],
#   'this': [35],
#   'project': [36, 66],
#   'was': [37, 67, 215, 281],
#   'mouse.': [39],
#   'This': [40],
#   'paper': [41],
#   'presents': [42],
#   'an': [43],
#   'overview': [44],
#   'scientific': [47],
#   'goals,': [48],
#   'experimental': [50],
#   'design': [51],
#   'and': [52, 71, 97, 117, 150, 166, 178, 196, 217, 222, 254, 283],
#   'mouse': [54],
#   'training/selection': [55],
#   'program.': [56],
#   'aim': [58],
#   'mice': [60, 89, 116, 126, 179, 192, 209, 246, 271, 286],
#   'experiments': [61],
#   'to': [68, 81, 161, 181, 188, 260],
#   'elucidate': [69],
#   'cellular': [70],
#   'molecular': [72],
#   'mechanisms,': [73],
#   'underlying': [74],
#   'adaptation': [76, 180],
#   'key': [78],
#   'physiological': [79],
#   'systems': [80],
#   'long-term': [82],
#   'exposure': [83],
#   'microgravity.': [85],
#   'studies': [87, 108, 214, 253],
#   'combined': [90],
#   'vivo': [92, 213],
#   'measurements,': [93],
#   'both': [94],
#   'post-flight': [98],
#   '(including': [99],
#   'continuous': [100, 223],
#   'blood': [101],
#   'pressure': [102],
#   'measurement),': [103],
#   'extensive': [105],
#   'vitro': [107],
#   'carried': [109],
#   'out': [110],
#   'shortly': [111],
#   'after': [112],
#   'return': [113],
#   'end': [120],
#   'recovery': [122],
#   'study.': [123],
#   'Male': [124],
#   'C57/BL6': [125],
#   'group': [127],
#   'housed': [128],
#   'space': [130, 292],
#   'habitats': [131],
#   'were': [132, 159, 235, 247],
#   'flown': [133],
#   'aboard': [134],
#   'biosatellite,': [138],
#   'or': [139],
#   'remained': [140],
#   'on': [141],
#   'ground': [142],
#   'control': [145, 157],
#   'experiment': [146],
#   'that': [147, 277, 284],
#   'replicated': [148],
#   'environmental': [149],
#   'housing': [151, 164, 176, 194],
#   'conditions': [152],
#   'spacecraft.': [155],
#   'Vivarium': [156],
#   'groups': [158, 177, 195],
#   'used': [160, 236],
#   'account': [162],
#   'effects': [165],
#   'possible': [167],
#   'seasonal': [168],
#   'differences.': [169],
#   'Mice': [170],
#   'training': [171, 206, 267, 279],
#   'included': [172, 218],
#   'co-adaptation': [174],
#   'paste': [182, 201],
#   'food': [183, 202],
#   'diet.': [184],
#   'measures': [186],
#   'taken': [187],
#   'co-adapt': [189],
#   'aggressive': [190],
#   'male': [191, 285],
#   'peculiarities': [198],
#   '"space"': [200],
#   'are': [203, 273],
#   'described.': [204],
#   'designated': [210],
#   'broader': [216],
#   'behavioral/functional': [219],
#   'test': [220],
#   'battery': [221],
#   'behavioral': [224],
#   'measurements': [225],
#   'home-cage.': [228],
#   'results': [230],
#   'preliminary': [233],
#   'tests': [234],
#   'selection': [239],
#   'homogenous': [241],
#   'groups.': [242],
#   'flight,': [245],
#   'good': [249],
#   'condition': [250],
#   'displayed': [255],
#   'signs': [256],
#   'pronounced': [258],
#   'disadaptation': [259],
#   "Earth's": [261],
#   'gravity.': [262],
#   'outcomes': [264],
#   'welfare': [272],
#   'discussed.': [274],
#   'We': [275],
#   'conclude': [276],
#   'our': [278],
#   'effective': [282],
#   'can': [287],
#   'be': [288],
#   'successfully': [289],
#   'employed': [290],
#   'research.': [294]},
#  'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2024980514',
#  'counts_by_year': [{'year': 2025, 'cited_by_count': 2},
#   {'year': 2024, 'cited_by_count': 4},
#   {'year': 2023, 'cited_by_count': 8},
#   {'year': 2022, 'cited_by_count': 6},
#   {'year': 2021, 'cited_by_count': 12},
#   {'year': 2020, 'cited_by_count': 11},
#   {'year': 2019, 'cited_by_count': 13},
#   {'year': 2018, 'cited_by_count': 10},
#   {'year': 2017, 'cited_by_count': 12},
#   {'year': 2016, 'cited_by_count': 3},
#   {'year': 2015, 'cited_by_count': 9},
#   {'year': 2014, 'cited_by_count': 1}],
#  'updated_date': '2025-09-15T18:35:54.614841',
#  'created_date': '2016-06-24'}

# %%
w.keys()
# Out:
# dict_keys(['id', 'doi', 'title', 'display_name', 'relevance_score', 'publication_year', 'publication_date', 'ids', 'language', 'primary_location', 'type', 'type_crossref', 'indexed_in', 'open_access', 'authorships', 'institution_assertions', 'countries_distinct_count', 'institutions_distinct_count', 'corresponding_author_ids', 'corresponding_institution_ids', 'apc_list', 'apc_paid', 'fwci', 'has_fulltext', 'fulltext_origin', 'cited_by_count', 'citation_normalized_percentile', 'cited_by_percentile_year', 'biblio', 'is_retracted', 'is_paratext', 'primary_topic', 'topics', 'keywords', 'concepts', 'mesh', 'locations_count', 'locations', 'best_oa_location', 'sustainable_development_goals', 'grants', 'datasets', 'versions', 'referenced_works_count', 'referenced_works', 'related_works', 'abstract_inverted_index', 'cited_by_api_url', 'counts_by_year', 'updated_date', 'created_date'])

# %%
w['keywords']
# Out:
# []

# %%
print(json.dumps(w, indent=4))
# Out:
# {
#     "id": "https://openalex.org/W2024980514",
#     "doi": "https://doi.org/10.1371/journal.pone.0104830",
#     "title": "Mice in Bion-M 1 Space Mission: Training and Selection",
#     "display_name": "Mice in Bion-M 1 Space Mission: Training and Selection",
#     "relevance_score": 1827.8414,
#     "publication_year": 2014,
#     "publication_date": "2014-08-18",
#     "ids": {
#         "openalex": "https://openalex.org/W2024980514",
#         "doi": "https://doi.org/10.1371/journal.pone.0104830",
#         "mag": "2024980514",
#         "pmid": "https://pubmed.ncbi.nlm.nih.gov/25133741",
#         "pmcid": "https://www.ncbi.nlm.nih.gov/pmc/articles/4136787"
#     },
#     "language": "en",
#     "primary_location": {
#         "is_oa": true,
#         "landing_page_url": "https://doi.org/10.1371/journal.pone.0104830",
#         "pdf_url": "https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0104830&type=printable",
#         "source": {
#             "id": "https://openalex.org/S202381698",
#             "display_name": "PLoS ONE",
#             "issn_l": "1932-6203",
#             "issn": [
#                 "1932-6203"
#             ],
#             "is_oa": true,
#             "is_in_doaj": true,
#             "is_indexed_in_scopus": true,
#             "is_core": true,
#             "host_organization": "https://openalex.org/P4310315706",
#             "host_organization_name": "Public Library of Science",
#             "host_organization_lineage": [
#                 "https://openalex.org/P4310315706"
#             ],
#             "host_organization_lineage_names": [
#                 "Public Library of Science"
#             ],
#             "type": "journal"
#         },
#         "license": "cc-by",
#         "license_id": "https://openalex.org/licenses/cc-by",
#         "version": "publishedVersion",
#         "is_accepted": true,
#         "is_published": true
#     },
#     "type": "article",
#     "type_crossref": "journal-article",
#     "indexed_in": [
#         "crossref",
#         "doaj",
#         "pubmed"
#     ],
#     "open_access": {
#         "is_oa": true,
#         "oa_status": "gold",
#         "oa_url": "https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0104830&type=printable",
#         "any_repository_has_fulltext": true
#     },
#     "authorships": [
#         {
#             "author_position": "first",
#             "author": {
#                 "id": "https://openalex.org/A5007682145",
#                 "display_name": "Alexander Andreev\u2010Andrievskiy",
#                 "orcid": "https://orcid.org/0000-0002-1173-8153"
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I4210101246",
#                     "display_name": "Institute of Biomedical Problems",
#                     "ror": "https://ror.org/016hfp155",
#                     "country_code": "RU",
#                     "type": "facility",
#                     "lineage": [
#                         "https://openalex.org/I1313323035",
#                         "https://openalex.org/I4210101246",
#                         "https://openalex.org/I4210115279"
#                     ]
#                 },
#                 {
#                     "id": "https://openalex.org/I19880235",
#                     "display_name": "Lomonosov Moscow State University",
#                     "ror": "https://ror.org/010pmpe69",
#                     "country_code": "RU",
#                     "type": "funder",
#                     "lineage": [
#                         "https://openalex.org/I19880235"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "RU"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Alexander Andreev-Andrievskiy",
#             "raw_affiliation_strings": [
#                 "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia",
#                 "Moscow State University, Biology Faculty, Moscow, Russia"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I4210101246"
#                     ]
#                 },
#                 {
#                     "raw_affiliation_string": "Moscow State University, Biology Faculty, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I19880235"
#                     ]
#                 }
#             ]
#         },
#         {
#             "author_position": "middle",
#             "author": {
#                 "id": "https://openalex.org/A5102865109",
#                 "display_name": "Anfisa Popova",
#                 "orcid": "https://orcid.org/0000-0002-7827-9764"
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I4210101246",
#                     "display_name": "Institute of Biomedical Problems",
#                     "ror": "https://ror.org/016hfp155",
#                     "country_code": "RU",
#                     "type": "facility",
#                     "lineage": [
#                         "https://openalex.org/I1313323035",
#                         "https://openalex.org/I4210101246",
#                         "https://openalex.org/I4210115279"
#                     ]
#                 },
#                 {
#                     "id": "https://openalex.org/I19880235",
#                     "display_name": "Lomonosov Moscow State University",
#                     "ror": "https://ror.org/010pmpe69",
#                     "country_code": "RU",
#                     "type": "funder",
#                     "lineage": [
#                         "https://openalex.org/I19880235"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "RU"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Anfisa Popova",
#             "raw_affiliation_strings": [
#                 "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia",
#                 "Moscow State University, Biology Faculty, Moscow, Russia"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I4210101246"
#                     ]
#                 },
#                 {
#                     "raw_affiliation_string": "Moscow State University, Biology Faculty, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I19880235"
#                     ]
#                 }
#             ]
#         },
#         {
#             "author_position": "middle",
#             "author": {
#                 "id": "https://openalex.org/A5102855830",
#                 "display_name": "Richard Boyle",
#                 "orcid": "https://orcid.org/0000-0001-9305-5024"
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I1280536761",
#                     "display_name": "Ames Research Center",
#                     "ror": "https://ror.org/02acart68",
#                     "country_code": "US",
#                     "type": "funder",
#                     "lineage": [
#                         "https://openalex.org/I1280536761",
#                         "https://openalex.org/I4210124779"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "US"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Richard Boyle",
#             "raw_affiliation_strings": [
#                 "Bio-Visualization, Imaging and Simulation Technology Center (BioVIS), NASA Ames Research Center, Moffett Field, California, United States of America"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Bio-Visualization, Imaging and Simulation Technology Center (BioVIS), NASA Ames Research Center, Moffett Field, California, United States of America",
#                     "institution_ids": [
#                         "https://openalex.org/I1280536761"
#                     ]
#                 }
#             ]
#         },
#         {
#             "author_position": "middle",
#             "author": {
#                 "id": "https://openalex.org/A5003466788",
#                 "display_name": "Jeffrey R. Alberts",
#                 "orcid": "https://orcid.org/0000-0003-2104-6297"
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I4210119109",
#                     "display_name": "Indiana University Bloomington",
#                     "ror": "https://ror.org/02k40bc56",
#                     "country_code": "US",
#                     "type": "funder",
#                     "lineage": [
#                         "https://openalex.org/I4210119109",
#                         "https://openalex.org/I592451"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "US"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Jeffrey Alberts",
#             "raw_affiliation_strings": [
#                 "Indiana University, Department of Psychological and Brain Sciences, Bloomington, Indiana, United States of America"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Indiana University, Department of Psychological and Brain Sciences, Bloomington, Indiana, United States of America",
#                     "institution_ids": [
#                         "https://openalex.org/I4210119109"
#                     ]
#                 }
#             ]
#         },
#         {
#             "author_position": "middle",
#             "author": {
#                 "id": "https://openalex.org/A5103900094",
#                 "display_name": "Boris Shenkman",
#                 "orcid": null
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I4210101246",
#                     "display_name": "Institute of Biomedical Problems",
#                     "ror": "https://ror.org/016hfp155",
#                     "country_code": "RU",
#                     "type": "facility",
#                     "lineage": [
#                         "https://openalex.org/I1313323035",
#                         "https://openalex.org/I4210101246",
#                         "https://openalex.org/I4210115279"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "RU"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Boris Shenkman",
#             "raw_affiliation_strings": [
#                 "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I4210101246"
#                     ]
#                 }
#             ]
#         },
#         {
#             "author_position": "middle",
#             "author": {
#                 "id": "https://openalex.org/A5108039862",
#                 "display_name": "\u041e. \u041b. \u0412\u0438\u043d\u043e\u0433\u0440\u0430\u0434\u043e\u0432\u0430",
#                 "orcid": "https://orcid.org/0000-0002-4622-0522"
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I4210101246",
#                     "display_name": "Institute of Biomedical Problems",
#                     "ror": "https://ror.org/016hfp155",
#                     "country_code": "RU",
#                     "type": "facility",
#                     "lineage": [
#                         "https://openalex.org/I1313323035",
#                         "https://openalex.org/I4210101246",
#                         "https://openalex.org/I4210115279"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "RU"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Olga Vinogradova",
#             "raw_affiliation_strings": [
#                 "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I4210101246"
#                     ]
#                 }
#             ]
#         },
#         {
#             "author_position": "middle",
#             "author": {
#                 "id": "https://openalex.org/A5000072952",
#                 "display_name": "Oleg Dolgov",
#                 "orcid": null
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I4210154072",
#                     "display_name": "Institute of Normal Physiology named after P.K. Anokhin",
#                     "ror": "https://ror.org/04kakt857",
#                     "country_code": "RU",
#                     "type": "funder",
#                     "lineage": [
#                         "https://openalex.org/I1313323035",
#                         "https://openalex.org/I4210110862",
#                         "https://openalex.org/I4210154072"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "RU"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Oleg Dolgov",
#             "raw_affiliation_strings": [
#                 "Anokhin Institute of Normal Physiology, Russian Academy of Medical Sciences, Moscow, Russia"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Anokhin Institute of Normal Physiology, Russian Academy of Medical Sciences, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I4210154072"
#                     ]
#                 }
#             ]
#         },
#         {
#             "author_position": "middle",
#             "author": {
#                 "id": "https://openalex.org/A5007929999",
#                 "display_name": "K. V. Anokhin",
#                 "orcid": "https://orcid.org/0000-0003-4437-6002"
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I2800235667",
#                     "display_name": "Kurchatov Institute",
#                     "ror": "https://ror.org/00n1nz186",
#                     "country_code": "RU",
#                     "type": "facility",
#                     "lineage": [
#                         "https://openalex.org/I2800235667"
#                     ]
#                 },
#                 {
#                     "id": "https://openalex.org/I4210154072",
#                     "display_name": "Institute of Normal Physiology named after P.K. Anokhin",
#                     "ror": "https://ror.org/04kakt857",
#                     "country_code": "RU",
#                     "type": "funder",
#                     "lineage": [
#                         "https://openalex.org/I1313323035",
#                         "https://openalex.org/I4210110862",
#                         "https://openalex.org/I4210154072"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "RU"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Konstantin Anokhin",
#             "raw_affiliation_strings": [
#                 "Anokhin Institute of Normal Physiology, Russian Academy of Medical Sciences, Moscow, Russia",
#                 "Kurchatov NBIC-center, National Research Centre \"Kurchatov Institute\", Moscow, Russia"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Kurchatov NBIC-center, National Research Centre \"Kurchatov Institute\", Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I2800235667"
#                     ]
#                 },
#                 {
#                     "raw_affiliation_string": "Anokhin Institute of Normal Physiology, Russian Academy of Medical Sciences, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I4210154072"
#                     ]
#                 }
#             ]
#         },
#         {
#             "author_position": "middle",
#             "author": {
#                 "id": "https://openalex.org/A5065942851",
#                 "display_name": "Daria Tsvirkun",
#                 "orcid": "https://orcid.org/0000-0002-6599-6844"
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I4210101246",
#                     "display_name": "Institute of Biomedical Problems",
#                     "ror": "https://ror.org/016hfp155",
#                     "country_code": "RU",
#                     "type": "facility",
#                     "lineage": [
#                         "https://openalex.org/I1313323035",
#                         "https://openalex.org/I4210101246",
#                         "https://openalex.org/I4210115279"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "RU"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Darya Tsvirkun",
#             "raw_affiliation_strings": [
#                 "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I4210101246"
#                     ]
#                 }
#             ]
#         },
#         {
#             "author_position": "middle",
#             "author": {
#                 "id": "https://openalex.org/A5003302980",
#                 "display_name": "\u041f. \u0415. \u0421\u043e\u043b\u0434\u0430\u0442\u043e\u0432",
#                 "orcid": "https://orcid.org/0000-0002-5318-4531"
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I4210101246",
#                     "display_name": "Institute of Biomedical Problems",
#                     "ror": "https://ror.org/016hfp155",
#                     "country_code": "RU",
#                     "type": "facility",
#                     "lineage": [
#                         "https://openalex.org/I1313323035",
#                         "https://openalex.org/I4210101246",
#                         "https://openalex.org/I4210115279"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "RU"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Pavel Soldatov",
#             "raw_affiliation_strings": [
#                 "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I4210101246"
#                     ]
#                 }
#             ]
#         },
#         {
#             "author_position": "middle",
#             "author": {
#                 "id": "https://openalex.org/A5103394824",
#                 "display_name": "Tatyana L. Nemirovskaya",
#                 "orcid": null
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I4210101246",
#                     "display_name": "Institute of Biomedical Problems",
#                     "ror": "https://ror.org/016hfp155",
#                     "country_code": "RU",
#                     "type": "facility",
#                     "lineage": [
#                         "https://openalex.org/I1313323035",
#                         "https://openalex.org/I4210101246",
#                         "https://openalex.org/I4210115279"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "RU"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Tatyana Nemirovskaya",
#             "raw_affiliation_strings": [
#                 "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I4210101246"
#                     ]
#                 }
#             ]
#         },
#         {
#             "author_position": "middle",
#             "author": {
#                 "id": "https://openalex.org/A5111514436",
#                 "display_name": "\u0415.\u0410. Ilyin",
#                 "orcid": null
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I4210101246",
#                     "display_name": "Institute of Biomedical Problems",
#                     "ror": "https://ror.org/016hfp155",
#                     "country_code": "RU",
#                     "type": "facility",
#                     "lineage": [
#                         "https://openalex.org/I1313323035",
#                         "https://openalex.org/I4210101246",
#                         "https://openalex.org/I4210115279"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "RU"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Eugeniy Ilyin",
#             "raw_affiliation_strings": [
#                 "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I4210101246"
#                     ]
#                 }
#             ]
#         },
#         {
#             "author_position": "last",
#             "author": {
#                 "id": "https://openalex.org/A5088403596",
#                 "display_name": "Vladimir Sychev",
#                 "orcid": "https://orcid.org/0000-0001-7508-9087"
#             },
#             "institutions": [
#                 {
#                     "id": "https://openalex.org/I4210101246",
#                     "display_name": "Institute of Biomedical Problems",
#                     "ror": "https://ror.org/016hfp155",
#                     "country_code": "RU",
#                     "type": "facility",
#                     "lineage": [
#                         "https://openalex.org/I1313323035",
#                         "https://openalex.org/I4210101246",
#                         "https://openalex.org/I4210115279"
#                     ]
#                 }
#             ],
#             "countries": [
#                 "RU"
#             ],
#             "is_corresponding": true,
#             "raw_author_name": "Vladimir Sychev",
#             "raw_affiliation_strings": [
#                 "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia"
#             ],
#             "affiliations": [
#                 {
#                     "raw_affiliation_string": "Institute for Biomedical Problems, Russian Academy of Sciences, Moscow, Russia",
#                     "institution_ids": [
#                         "https://openalex.org/I4210101246"
#                     ]
#                 }
#             ]
#         }
#     ],
#     "institution_assertions": [],
#     "countries_distinct_count": 2,
#     "institutions_distinct_count": 6,
#     "corresponding_author_ids": [
#         "https://openalex.org/A5007682145",
#         "https://openalex.org/A5102865109",
#         "https://openalex.org/A5102855830",
#         "https://openalex.org/A5003466788",
#         "https://openalex.org/A5103900094",
#         "https://openalex.org/A5108039862",
#         "https://openalex.org/A5000072952",
#         "https://openalex.org/A5007929999",
#         "https://openalex.org/A5065942851",
#         "https://openalex.org/A5003302980",
#         "https://openalex.org/A5103394824",
#         "https://openalex.org/A5111514436",
#         "https://openalex.org/A5088403596"
#     ],
#     "corresponding_institution_ids": [
#         "https://openalex.org/I4210101246",
#         "https://openalex.org/I19880235",
#         "https://openalex.org/I4210101246",
#         "https://openalex.org/I19880235",
#         "https://openalex.org/I1280536761",
#         "https://openalex.org/I4210119109",
#         "https://openalex.org/I4210101246",
#         "https://openalex.org/I4210101246",
#         "https://openalex.org/I4210154072",
#         "https://openalex.org/I2800235667",
#         "https://openalex.org/I4210154072",
#         "https://openalex.org/I4210101246",
#         "https://openalex.org/I4210101246",
#         "https://openalex.org/I4210101246",
#         "https://openalex.org/I4210101246",
#         "https://openalex.org/I4210101246"
#     ],
#     "apc_list": {
#         "value": 1805,
#         "currency": "USD",
#         "value_usd": 1805
#     },
#     "apc_paid": {
#         "value": 1805,
#         "currency": "USD",
#         "value_usd": 1805
#     },
#     "fwci": 4.703,
#     "has_fulltext": true,
#     "fulltext_origin": "pdf",
#     "cited_by_count": 91,
#     "citation_normalized_percentile": {
#         "value": 0.999952,
#         "is_in_top_1_percent": true,
#         "is_in_top_10_percent": true
#     },
#     "cited_by_percentile_year": {
#         "min": 97,
#         "max": 98
#     },
#     "biblio": {
#         "volume": "9",
#         "issue": "8",
#         "first_page": "e104830",
#         "last_page": "e104830"
#     },
#     "is_retracted": false,
#     "is_paratext": false,
#     "primary_topic": {
#         "id": "https://openalex.org/T12005",
#         "display_name": "Spaceflight effects on biology",
#         "score": 0.9995,
#         "subfield": {
#             "id": "https://openalex.org/subfields/2737",
#             "display_name": "Physiology"
#         },
#         "field": {
#             "id": "https://openalex.org/fields/27",
#             "display_name": "Medicine"
#         },
#         "domain": {
#             "id": "https://openalex.org/domains/4",
#             "display_name": "Health Sciences"
#         }
#     },
#     "topics": [
#         {
#             "id": "https://openalex.org/T12005",
#             "display_name": "Spaceflight effects on biology",
#             "score": 0.9995,
#             "subfield": {
#                 "id": "https://openalex.org/subfields/2737",
#                 "display_name": "Physiology"
#             },
#             "field": {
#                 "id": "https://openalex.org/fields/27",
#                 "display_name": "Medicine"
#             },
#             "domain": {
#                 "id": "https://openalex.org/domains/4",
#                 "display_name": "Health Sciences"
#             }
#         }
#     ],
#     "keywords": [],
#     "concepts": [
#         {
#             "id": "https://openalex.org/C81917197",
#             "wikidata": "https://www.wikidata.org/wiki/Q628760",
#             "display_name": "Selection (genetic algorithm)",
#             "level": 2,
#             "score": 0.57971156
#         },
#         {
#             "id": "https://openalex.org/C2778572836",
#             "wikidata": "https://www.wikidata.org/wiki/Q380933",
#             "display_name": "Space (punctuation)",
#             "level": 2,
#             "score": 0.45162693
#         },
#         {
#             "id": "https://openalex.org/C70721500",
#             "wikidata": "https://www.wikidata.org/wiki/Q177005",
#             "display_name": "Computational biology",
#             "level": 1,
#             "score": 0.43779275
#         },
#         {
#             "id": "https://openalex.org/C41008148",
#             "wikidata": "https://www.wikidata.org/wiki/Q21198",
#             "display_name": "Computer science",
#             "level": 0,
#             "score": 0.37105697
#         },
#         {
#             "id": "https://openalex.org/C86803240",
#             "wikidata": "https://www.wikidata.org/wiki/Q420",
#             "display_name": "Biology",
#             "level": 0,
#             "score": 0.34196806
#         },
#         {
#             "id": "https://openalex.org/C154945302",
#             "wikidata": "https://www.wikidata.org/wiki/Q11660",
#             "display_name": "Artificial intelligence",
#             "level": 1,
#             "score": 0.25689316
#         },
#         {
#             "id": "https://openalex.org/C111919701",
#             "wikidata": "https://www.wikidata.org/wiki/Q9135",
#             "display_name": "Operating system",
#             "level": 1,
#             "score": 0.0
#         }
#     ],
#     "mesh": [
#         {
#             "descriptor_ui": "D000222",
#             "descriptor_name": "Adaptation, Physiological",
#             "qualifier_ui": "",
#             "qualifier_name": null,
#             "is_major_topic": false
#         },
#         {
#             "descriptor_ui": "D000818",
#             "descriptor_name": "Animals",
#             "qualifier_ui": "",
#             "qualifier_name": null,
#             "is_major_topic": false
#         },
#         {
#             "descriptor_ui": "D035843",
#             "descriptor_name": "Biomedical Research",
#             "qualifier_ui": "",
#             "qualifier_name": null,
#             "is_major_topic": false
#         },
#         {
#             "descriptor_ui": "D004435",
#             "descriptor_name": "Eating",
#             "qualifier_ui": "",
#             "qualifier_name": null,
#             "is_major_topic": false
#         },
#         {
#             "descriptor_ui": "D006799",
#             "descriptor_name": "Housing, Animal",
#             "qualifier_ui": "",
#             "qualifier_name": null,
#             "is_major_topic": false
#         },
#         {
#             "descriptor_ui": "D008297",
#             "descriptor_name": "Male",
#             "qualifier_ui": "",
#             "qualifier_name": null,
#             "is_major_topic": false
#         },
#         {
#             "descriptor_ui": "D008810",
#             "descriptor_name": "Mice, Inbred C57BL",
#             "qualifier_ui": "",
#             "qualifier_name": null,
#             "is_major_topic": false
#         },
#         {
#             "descriptor_ui": "D010805",
#             "descriptor_name": "Physical Conditioning, Animal",
#             "qualifier_ui": "",
#             "qualifier_name": null,
#             "is_major_topic": false
#         },
#         {
#             "descriptor_ui": "D012107",
#             "descriptor_name": "Research Design",
#             "qualifier_ui": "",
#             "qualifier_name": null,
#             "is_major_topic": false
#         },
#         {
#             "descriptor_ui": "D012426",
#             "descriptor_name": "Russia",
#             "qualifier_ui": "",
#             "qualifier_name": null,
#             "is_major_topic": false
#         },
#         {
#             "descriptor_ui": "D013026",
#             "descriptor_name": "Space Flight",
#             "qualifier_ui": "",
#             "qualifier_name": null,
#             "is_major_topic": false
#         },
#         {
#             "descriptor_ui": "D014893",
#             "descriptor_name": "Weightlessness",
#             "qualifier_ui": "",
#             "qualifier_name": null,
#             "is_major_topic": false
#         }
#     ],
#     "locations_count": 5,
#     "locations": [
#         {
#             "is_oa": true,
#             "landing_page_url": "https://doi.org/10.1371/journal.pone.0104830",
#             "pdf_url": "https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0104830&type=printable",
#             "source": {
#                 "id": "https://openalex.org/S202381698",
#                 "display_name": "PLoS ONE",
#                 "issn_l": "1932-6203",
#                 "issn": [
#                     "1932-6203"
#                 ],
#                 "is_oa": true,
#                 "is_in_doaj": true,
#                 "is_indexed_in_scopus": true,
#                 "is_core": true,
#                 "host_organization": "https://openalex.org/P4310315706",
#                 "host_organization_name": "Public Library of Science",
#                 "host_organization_lineage": [
#                     "https://openalex.org/P4310315706"
#                 ],
#                 "host_organization_lineage_names": [
#                     "Public Library of Science"
#                 ],
#                 "type": "journal"
#             },
#             "license": "cc-by",
#             "license_id": "https://openalex.org/licenses/cc-by",
#             "version": "publishedVersion",
#             "is_accepted": true,
#             "is_published": true
#         },
#         {
#             "is_oa": false,
#             "landing_page_url": "https://doaj.org/article/9468c812a611470697eb46b323210b04",
#             "pdf_url": null,
#             "source": {
#                 "id": "https://openalex.org/S4306401280",
#                 "display_name": "DOAJ (DOAJ: Directory of Open Access Journals)",
#                 "issn_l": null,
#                 "issn": null,
#                 "is_oa": true,
#                 "is_in_doaj": false,
#                 "is_indexed_in_scopus": false,
#                 "is_core": false,
#                 "host_organization": null,
#                 "host_organization_name": null,
#                 "host_organization_lineage": [],
#                 "host_organization_lineage_names": [],
#                 "type": "repository"
#             },
#             "license": null,
#             "license_id": null,
#             "version": null,
#             "is_accepted": false,
#             "is_published": false
#         },
#         {
#             "is_oa": true,
#             "landing_page_url": "https://europepmc.org/articles/pmc4136787",
#             "pdf_url": "https://europepmc.org/articles/pmc4136787?pdf=render",
#             "source": {
#                 "id": "https://openalex.org/S4306400806",
#                 "display_name": "Europe PMC (PubMed Central)",
#                 "issn_l": null,
#                 "issn": null,
#                 "is_oa": true,
#                 "is_in_doaj": false,
#                 "is_indexed_in_scopus": false,
#                 "is_core": false,
#                 "host_organization": "https://openalex.org/I1303153112",
#                 "host_organization_name": "European Bioinformatics Institute",
#                 "host_organization_lineage": [
#                     "https://openalex.org/I1303153112"
#                 ],
#                 "host_organization_lineage_names": [
#                     "European Bioinformatics Institute"
#                 ],
#                 "type": "repository"
#             },
#             "license": null,
#             "license_id": null,
#             "version": "publishedVersion",
#             "is_accepted": true,
#             "is_published": true
#         },
#         {
#             "is_oa": true,
#             "landing_page_url": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4136787",
#             "pdf_url": null,
#             "source": {
#                 "id": "https://openalex.org/S2764455111",
#                 "display_name": "PubMed Central",
#                 "issn_l": null,
#                 "issn": null,
#                 "is_oa": true,
#                 "is_in_doaj": false,
#                 "is_indexed_in_scopus": false,
#                 "is_core": false,
#                 "host_organization": "https://openalex.org/I1299303238",
#                 "host_organization_name": "National Institutes of Health",
#                 "host_organization_lineage": [
#                     "https://openalex.org/I1299303238"
#                 ],
#                 "host_organization_lineage_names": [
#                     "National Institutes of Health"
#                 ],
#                 "type": "repository"
#             },
#             "license": null,
#             "license_id": null,
#             "version": "publishedVersion",
#             "is_accepted": true,
#             "is_published": true
#         },
#         {
#             "is_oa": false,
#             "landing_page_url": "https://pubmed.ncbi.nlm.nih.gov/25133741",
#             "pdf_url": null,
#             "source": {
#                 "id": "https://openalex.org/S4306525036",
#                 "display_name": "PubMed",
#                 "issn_l": null,
#                 "issn": null,
#                 "is_oa": false,
#                 "is_in_doaj": false,
#                 "is_indexed_in_scopus": false,
#                 "is_core": false,
#                 "host_organization": "https://openalex.org/I1299303238",
#                 "host_organization_name": "National Institutes of Health",
#                 "host_organization_lineage": [
#                     "https://openalex.org/I1299303238"
#                 ],
#                 "host_organization_lineage_names": [
#                     "National Institutes of Health"
#                 ],
#                 "type": "repository"
#             },
#             "license": null,
#             "license_id": null,
#             "version": null,
#             "is_accepted": false,
#             "is_published": false
#         }
#     ],
#     "best_oa_location": {
#         "is_oa": true,
#         "landing_page_url": "https://doi.org/10.1371/journal.pone.0104830",
#         "pdf_url": "https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0104830&type=printable",
#         "source": {
#             "id": "https://openalex.org/S202381698",
#             "display_name": "PLoS ONE",
#             "issn_l": "1932-6203",
#             "issn": [
#                 "1932-6203"
#             ],
#             "is_oa": true,
#             "is_in_doaj": true,
#             "is_indexed_in_scopus": true,
#             "is_core": true,
#             "host_organization": "https://openalex.org/P4310315706",
#             "host_organization_name": "Public Library of Science",
#             "host_organization_lineage": [
#                 "https://openalex.org/P4310315706"
#             ],
#             "host_organization_lineage_names": [
#                 "Public Library of Science"
#             ],
#             "type": "journal"
#         },
#         "license": "cc-by",
#         "license_id": "https://openalex.org/licenses/cc-by",
#         "version": "publishedVersion",
#         "is_accepted": true,
#         "is_published": true
#     },
#     "sustainable_development_goals": [],
#     "grants": [],
#     "datasets": [],
#     "versions": [],
#     "referenced_works_count": 37,
#     "referenced_works": [
#         "https://openalex.org/W1505364969",
#         "https://openalex.org/W1554739571",
#         "https://openalex.org/W1591327376",
#         "https://openalex.org/W1619036177",
#         "https://openalex.org/W1969581053",
#         "https://openalex.org/W1971410406",
#         "https://openalex.org/W1971846039",
#         "https://openalex.org/W1983439863",
#         "https://openalex.org/W1987412703",
#         "https://openalex.org/W1993340066",
#         "https://openalex.org/W1997095406",
#         "https://openalex.org/W1999858993",
#         "https://openalex.org/W2007302154",
#         "https://openalex.org/W2018002860",
#         "https://openalex.org/W2032606415",
#         "https://openalex.org/W2037241677",
#         "https://openalex.org/W2044143697",
#         "https://openalex.org/W2056883423",
#         "https://openalex.org/W2058934156",
#         "https://openalex.org/W2063848772",
#         "https://openalex.org/W2087151156",
#         "https://openalex.org/W2089680506",
#         "https://openalex.org/W2095510407",
#         "https://openalex.org/W2096916192",
#         "https://openalex.org/W2101954244",
#         "https://openalex.org/W2123250581",
#         "https://openalex.org/W2137856862",
#         "https://openalex.org/W2146215923",
#         "https://openalex.org/W2160801689",
#         "https://openalex.org/W2169205637",
#         "https://openalex.org/W2184493357",
#         "https://openalex.org/W2416126827",
#         "https://openalex.org/W2487019969",
#         "https://openalex.org/W2955504961",
#         "https://openalex.org/W4232424793",
#         "https://openalex.org/W569272410",
#         "https://openalex.org/W9377703"
#     ],
#     "related_works": [
#         "https://openalex.org/W4391375266",
#         "https://openalex.org/W2899084033",
#         "https://openalex.org/W2788277189",
#         "https://openalex.org/W2748952813",
#         "https://openalex.org/W2130076355",
#         "https://openalex.org/W2119695867",
#         "https://openalex.org/W2082860237",
#         "https://openalex.org/W2046158694",
#         "https://openalex.org/W1993764875",
#         "https://openalex.org/W1990804418"
#     ],
#     "abstract_inverted_index": {
#         "After": [
#             0,
#             243
#         ],
#         "a": [
#             1
#         ],
#         "16-year": [
#             2
#         ],
#         "hiatus,": [
#             3
#         ],
#         "Russia": [
#             4
#         ],
#         "has": [
#             5
#         ],
#         "resumed": [
#             6
#         ],
#         "its": [
#             7
#         ],
#         "program": [
#             8,
#             207,
#             268,
#             280
#         ],
#         "of": [
#             9,
#             19,
#             45,
#             59,
#             77,
#             114,
#             121,
#             199,
#             231,
#             240,
#             257,
#             265
#         ],
#         "biomedical": [
#             10,
#             32,
#             252,
#             293
#         ],
#         "research": [
#             11,
#             33
#         ],
#         "in": [
#             12,
#             34,
#             62,
#             84,
#             91,
#             95,
#             106,
#             118,
#             129,
#             143,
#             153,
#             175,
#             193,
#             212,
#             226,
#             248,
#             291
#         ],
#         "space,": [
#             13
#         ],
#         "with": [
#             14,
#             88,
#             104
#         ],
#         "the": [
#             15,
#             20,
#             38,
#             46,
#             49,
#             53,
#             63,
#             75,
#             115,
#             119,
#             135,
#             144,
#             154,
#             173,
#             197,
#             227,
#             232,
#             238,
#             244,
#             266,
#             270
#         ],
#         "successful": [
#             16
#         ],
#         "30-day": [
#             17
#         ],
#         "flight": [
#             18,
#             96
#         ],
#         "Bion-M": [
#             21,
#             64,
#             136
#         ],
#         "1": [
#             22,
#             65,
#             137
#         ],
#         "biosatellite": [
#             23
#         ],
#         "(April": [
#             24
#         ],
#         "19-May": [
#             25
#         ],
#         "19,": [
#             26
#         ],
#         "2013).": [
#             27
#         ],
#         "The": [
#             28,
#             57,
#             86,
#             185,
#             205,
#             229,
#             263
#         ],
#         "principal": [
#             29
#         ],
#         "species": [
#             30
#         ],
#         "for": [
#             31,
#             163,
#             208,
#             211,
#             237,
#             251,
#             269
#         ],
#         "this": [
#             35
#         ],
#         "project": [
#             36,
#             66
#         ],
#         "was": [
#             37,
#             67,
#             215,
#             281
#         ],
#         "mouse.": [
#             39
#         ],
#         "This": [
#             40
#         ],
#         "paper": [
#             41
#         ],
#         "presents": [
#             42
#         ],
#         "an": [
#             43
#         ],
#         "overview": [
#             44
#         ],
#         "scientific": [
#             47
#         ],
#         "goals,": [
#             48
#         ],
#         "experimental": [
#             50
#         ],
#         "design": [
#             51
#         ],
#         "and": [
#             52,
#             71,
#             97,
#             117,
#             150,
#             166,
#             178,
#             196,
#             217,
#             222,
#             254,
#             283
#         ],
#         "mouse": [
#             54
#         ],
#         "training/selection": [
#             55
#         ],
#         "program.": [
#             56
#         ],
#         "aim": [
#             58
#         ],
#         "mice": [
#             60,
#             89,
#             116,
#             126,
#             179,
#             192,
#             209,
#             246,
#             271,
#             286
#         ],
#         "experiments": [
#             61
#         ],
#         "to": [
#             68,
#             81,
#             161,
#             181,
#             188,
#             260
#         ],
#         "elucidate": [
#             69
#         ],
#         "cellular": [
#             70
#         ],
#         "molecular": [
#             72
#         ],
#         "mechanisms,": [
#             73
#         ],
#         "underlying": [
#             74
#         ],
#         "adaptation": [
#             76,
#             180
#         ],
#         "key": [
#             78
#         ],
#         "physiological": [
#             79
#         ],
#         "systems": [
#             80
#         ],
#         "long-term": [
#             82
#         ],
#         "exposure": [
#             83
#         ],
#         "microgravity.": [
#             85
#         ],
#         "studies": [
#             87,
#             108,
#             214,
#             253
#         ],
#         "combined": [
#             90
#         ],
#         "vivo": [
#             92,
#             213
#         ],
#         "measurements,": [
#             93
#         ],
#         "both": [
#             94
#         ],
#         "post-flight": [
#             98
#         ],
#         "(including": [
#             99
#         ],
#         "continuous": [
#             100,
#             223
#         ],
#         "blood": [
#             101
#         ],
#         "pressure": [
#             102
#         ],
#         "measurement),": [
#             103
#         ],
#         "extensive": [
#             105
#         ],
#         "vitro": [
#             107
#         ],
#         "carried": [
#             109
#         ],
#         "out": [
#             110
#         ],
#         "shortly": [
#             111
#         ],
#         "after": [
#             112
#         ],
#         "return": [
#             113
#         ],
#         "end": [
#             120
#         ],
#         "recovery": [
#             122
#         ],
#         "study.": [
#             123
#         ],
#         "Male": [
#             124
#         ],
#         "C57/BL6": [
#             125
#         ],
#         "group": [
#             127
#         ],
#         "housed": [
#             128
#         ],
#         "space": [
#             130,
#             292
#         ],
#         "habitats": [
#             131
#         ],
#         "were": [
#             132,
#             159,
#             235,
#             247
#         ],
#         "flown": [
#             133
#         ],
#         "aboard": [
#             134
#         ],
#         "biosatellite,": [
#             138
#         ],
#         "or": [
#             139
#         ],
#         "remained": [
#             140
#         ],
#         "on": [
#             141
#         ],
#         "ground": [
#             142
#         ],
#         "control": [
#             145,
#             157
#         ],
#         "experiment": [
#             146
#         ],
#         "that": [
#             147,
#             277,
#             284
#         ],
#         "replicated": [
#             148
#         ],
#         "environmental": [
#             149
#         ],
#         "housing": [
#             151,
#             164,
#             176,
#             194
#         ],
#         "conditions": [
#             152
#         ],
#         "spacecraft.": [
#             155
#         ],
#         "Vivarium": [
#             156
#         ],
#         "groups": [
#             158,
#             177,
#             195
#         ],
#         "used": [
#             160,
#             236
#         ],
#         "account": [
#             162
#         ],
#         "effects": [
#             165
#         ],
#         "possible": [
#             167
#         ],
#         "seasonal": [
#             168
#         ],
#         "differences.": [
#             169
#         ],
#         "Mice": [
#             170
#         ],
#         "training": [
#             171,
#             206,
#             267,
#             279
#         ],
#         "included": [
#             172,
#             218
#         ],
#         "co-adaptation": [
#             174
#         ],
#         "paste": [
#             182,
#             201
#         ],
#         "food": [
#             183,
#             202
#         ],
#         "diet.": [
#             184
#         ],
#         "measures": [
#             186
#         ],
#         "taken": [
#             187
#         ],
#         "co-adapt": [
#             189
#         ],
#         "aggressive": [
#             190
#         ],
#         "male": [
#             191,
#             285
#         ],
#         "peculiarities": [
#             198
#         ],
#         "\"space\"": [
#             200
#         ],
#         "are": [
#             203,
#             273
#         ],
#         "described.": [
#             204
#         ],
#         "designated": [
#             210
#         ],
#         "broader": [
#             216
#         ],
#         "behavioral/functional": [
#             219
#         ],
#         "test": [
#             220
#         ],
#         "battery": [
#             221
#         ],
#         "behavioral": [
#             224
#         ],
#         "measurements": [
#             225
#         ],
#         "home-cage.": [
#             228
#         ],
#         "results": [
#             230
#         ],
#         "preliminary": [
#             233
#         ],
#         "tests": [
#             234
#         ],
#         "selection": [
#             239
#         ],
#         "homogenous": [
#             241
#         ],
#         "groups.": [
#             242
#         ],
#         "flight,": [
#             245
#         ],
#         "good": [
#             249
#         ],
#         "condition": [
#             250
#         ],
#         "displayed": [
#             255
#         ],
#         "signs": [
#             256
#         ],
#         "pronounced": [
#             258
#         ],
#         "disadaptation": [
#             259
#         ],
#         "Earth's": [
#             261
#         ],
#         "gravity.": [
#             262
#         ],
#         "outcomes": [
#             264
#         ],
#         "welfare": [
#             272
#         ],
#         "discussed.": [
#             274
#         ],
#         "We": [
#             275
#         ],
#         "conclude": [
#             276
#         ],
#         "our": [
#             278
#         ],
#         "effective": [
#             282
#         ],
#         "can": [
#             287
#         ],
#         "be": [
#             288
#         ],
#         "successfully": [
#             289
#         ],
#         "employed": [
#             290
#         ],
#         "research.": [
#             294
#         ]
#     },
#     "cited_by_api_url": "https://api.openalex.org/works?filter=cites:W2024980514",
#     "counts_by_year": [
#         {
#             "year": 2025,
#             "cited_by_count": 2
#         },
#         {
#             "year": 2024,
#             "cited_by_count": 4
#         },
#         {
#             "year": 2023,
#             "cited_by_count": 8
#         },
#         {
#             "year": 2022,
#             "cited_by_count": 6
#         },
#         {
#             "year": 2021,
#             "cited_by_count": 12
#         },
#         {
#             "year": 2020,
#             "cited_by_count": 11
#         },
#         {
#             "year": 2019,
#             "cited_by_count": 13
#         },
#         {
#             "year": 2018,
#             "cited_by_count": 10
#         },
#         {
#             "year": 2017,
#             "cited_by_count": 12
#         },
#         {
#             "year": 2016,
#             "cited_by_count": 3
#         },
#         {
#             "year": 2015,
#             "cited_by_count": 9
#         },
#         {
#             "year": 2014,
#             "cited_by_count": 1
#         }
#     ],
#     "updated_date": "2025-09-15T18:35:54.614841",
#     "created_date": "2016-06-24"
# }

# %%
w["abstract"]
# Out:
# 'After a 16-year hiatus, Russia has resumed its program of biomedical research in space, with the successful 30-day flight of the Bion-M 1 biosatellite (April 19-May 19, 2013). The principal species for biomedical research in this project was the mouse. This paper presents an overview of the scientific goals, the experimental design and the mouse training/selection program. The aim of mice experiments in the Bion-M 1 project was to elucidate cellular and molecular mechanisms, underlying the adaptation of key physiological systems to long-term exposure in microgravity. The studies with mice combined in vivo measurements, both in flight and post-flight (including continuous blood pressure measurement), with extensive in vitro studies carried out shortly after return of the mice and in the end of recovery study. Male C57/BL6 mice group housed in space habitats were flown aboard the Bion-M 1 biosatellite, or remained on ground in the control experiment that replicated environmental and housing conditions in the spacecraft. Vivarium control groups were used to account for housing effects and possible seasonal differences. Mice training included the co-adaptation in housing groups and mice adaptation to paste food diet. The measures taken to co-adapt aggressive male mice in housing groups and the peculiarities of "space" paste food are described. The training program for mice designated for in vivo studies was broader and included behavioral/functional test battery and continuous behavioral measurements in the home-cage. The results of the preliminary tests were used for the selection of homogenous groups. After the flight, mice were in good condition for biomedical studies and displayed signs of pronounced disadaptation to Earth\'s gravity. The outcomes of the training program for the mice welfare are discussed. We conclude that our training program was effective and that male mice can be successfully employed in space biomedical research.'

# %%
references = w["referenced_works"]
references
# Out:
# ['https://openalex.org/W1505364969',
#  'https://openalex.org/W1554739571',
#  'https://openalex.org/W1591327376',
#  'https://openalex.org/W1619036177',
#  'https://openalex.org/W1969581053',
#  'https://openalex.org/W1971410406',
#  'https://openalex.org/W1971846039',
#  'https://openalex.org/W1983439863',
#  'https://openalex.org/W1987412703',
#  'https://openalex.org/W1993340066',
#  'https://openalex.org/W1997095406',
#  'https://openalex.org/W1999858993',
#  'https://openalex.org/W2007302154',
#  'https://openalex.org/W2018002860',
#  'https://openalex.org/W2032606415',
#  'https://openalex.org/W2037241677',
#  'https://openalex.org/W2044143697',
#  'https://openalex.org/W2056883423',
#  'https://openalex.org/W2058934156',
#  'https://openalex.org/W2063848772',
#  'https://openalex.org/W2087151156',
#  'https://openalex.org/W2089680506',
#  'https://openalex.org/W2095510407',
#  'https://openalex.org/W2096916192',
#  'https://openalex.org/W2101954244',
#  'https://openalex.org/W2123250581',
#  'https://openalex.org/W2137856862',
#  'https://openalex.org/W2146215923',
#  'https://openalex.org/W2160801689',
#  'https://openalex.org/W2169205637',
#  'https://openalex.org/W2184493357',
#  'https://openalex.org/W2416126827',
#  'https://openalex.org/W2487019969',
#  'https://openalex.org/W2955504961',
#  'https://openalex.org/W4232424793',
#  'https://openalex.org/W569272410',
#  'https://openalex.org/W9377703']

# %%
len(references)
# Out:
# 37
